# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
def merge_rectangle(list_all_rect,threshold = 2):
    
    #print(list_all_rect)  
    merged_list = []
    start_point = []
    end_point = []
    final_list = []
    for i in range(len(list_all_rect)):
        list_curr = list_all_rect[i]
    
        if i == len(list_all_rect)-1:
            if start_point:
                merged_list.append(start_point+end_point)
            else:
                merged_list.append(list_all_rect[i])
            continue
    
        list_next = list_all_rect[i+1]

        diff = list_next[0] - list_curr[2]
    
        if diff <= threshold and not start_point:
            start_point = [list_curr[0],min(list_curr[1],list_next[1]),i]
            end_point   = [list_next[2],max(list_curr[3],list_next[3]),i+1]
    
        elif diff <= threshold:
            end_point   = [list_next[2],max(list_next[3],end_point[1]),i+1]
    
        else:
            if start_point:
                merged_list.append(start_point+end_point)
            else:
                merged_list.append(list_curr)
            start_point = []
            end_point   = []
  
    return merged_list

# %%
def optimize_merge_rectangle( list_all_rect , max_threshold_to_try = 5 , min_width = 50 , max_width = 200):
    
    #Trying directly max_threshold and then removing lengthy components
    
    merged_list = merge_rectangle(list_all_rect , max_threshold_to_try)
    
    # Removing lengthy Components
    # check for width of merged_component
    # we get the merged component if length is greater than 4 ie 6
    
    optimized_list = []
    
    for i in range(len(merged_list)):
        if len(merged_list[i])<6:
            optimized_list.append(merged_list[i])
            continue
        
        
        if abs(merged_list[i][0] - merged_list[i][3]) >= max_width:
            start_index = merged_list[i][2]
            end_index   = merged_list[i][5]
            print("Start_index",start_index,"End_index",end_index)
            for i in range(start_index,end_index+1):
                optimized_list.append(list_all_rect[i])
        else:
            optimized_list.append([merged_list[i][0],merged_list[i][1],merged_list[i][3],merged_list[i][4]])
    
    print(optimized_list)
    
    optimized_list = fix_smallWords(optimized_list , min_width)
    
    
    return optimized_list

# %%
def fix_smallWords(list_of_rect , min_width = 50):
    
    
    up_align  = 10
    dwn_align = 4
    
    # by how much length should be increase if component is small
    # and there is no nearby component to merge
    increase_length_by = 40
    
    list_of_short = []
    length = len(list_of_rect)
    i = 0
    while i < length :
        
        # index less than min_width needs fixing
        
        if abs(list_of_rect[i][0]-list_of_rect[i][2]) <= min_width :
            
            dist_left  = 999999999 
            dist_right = 999999999
            
            print(abs(list_of_rect[i][0]-list_of_rect[i][2]))
            
            if i!=0:
                dist_left  = abs(list_of_rect[i-1][2] - list_of_rect[i][0])
            if i!=len(list_of_rect)-1:
                dist_right = abs(list_of_rect[i][2] - list_of_rect[i+1][0]) 
            
            print("dist_left",dist_left,"dist_right",dist_right)
            # conditions for no nearby component
            if dist_left>55 and dist_right>55:
                list_temp = list_of_rect[i]
                list_temp[2]+=increase_length_by
                list_of_short.append(list_temp)
                
            
            elif dist_left >= 25 and  dist_right >= 60:
                list_temp = list_of_rect[i]
                list_temp[2]+=increase_length_by
                list_of_short.append(list_temp)
                
            #condition for selection betn nearby components
            #if nearby components are present then merge
            
            # In cursive writing
            # If we consider a word then , generally height of first charatere in word is greater than rest of character
            # and the base of rest of the character is either equal to or a bit higher than starting character
            # up_allign  = dist betn 1st char and rest char
            # down_align = dist betn base of rest of the char and starting character 
            
            elif dist_left<dist_right :
                if (list_of_rect[i][1]-list_of_rect[i-1][1] > 10) and (list_of_rect[i-1][3]-list_of_rect[i][3]>4):
                    list_of_short.append(list_of_rect[i])
                    print("1 inside continue")
                    continue 
                print("1 outside continue")
                list_prev = list_of_rect[i-1]
                list_curr = list_of_rect[i]
                #del list_of_rect[i]
                list_of_short.pop()
                list_of_short.append([list_prev[0],min(list_prev[1],list_curr[1]),list_curr[2],max(list_prev[3],list_curr[3])])
                
                
            elif dist_right<dist_left :
                if (list_of_rect[i+1][1]-list_of_rect[i][1] > 10) and (list_of_rect[i][3]-list_of_rect[i+1][3]>4):
                    list_of_short.append(list_of_rect[i])
                    print("2 inside continue")
                    continue
                print("2 outside continue")
                list_next = list_of_rect[i+1]
                list_curr = list_of_rect[i]
                #del list_of_rect[i]
                #del list_of_rect[i+1]
                list_of_short.append([list_curr[0],min(list_curr[1],list_next[1]),list_next[2],max(list_curr[3],list_next[3])])
                i = i+1

        else:
            list_of_short.append(list_of_rect[i])
        
        i = i+1
            
    return list_of_short

# %%
def do_segment(image) :
    
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    ret,thresh = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
    
    #kernel = np.ones((2,1), np.uint8)
    #img_eroded = cv2.erode(thresh, kernel, iterations=1)
    #cv2.imshow("Erode",img_eroded)
    #cv2.waitKey(0)
    #cv2.destroyAllWindows()
    
    kernel = np.ones((5,5), np.uint8)
    img_dilation = cv2.dilate(thresh, kernel, iterations=1)
    
    
    ctrs, hier = cv2.findContours(img_dilation.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    sorted_ctrs = sorted(ctrs, key=lambda ctr: cv2.boundingRect(ctr)[0])
    
    display1 = image.copy()
    list_all_rect = []
    for i, ctr in enumerate(sorted_ctrs):
    # Get bounding box
        x, y, w, h = cv2.boundingRect(ctr)
    
        threshold_width = width//5
        threshold_height = height//3
        print("Threshold Width",threshold_width)
        print("Threshold Height",threshold_height)
        
        if w<=threshold_width and h<=threshold_height :
            continue
            
        print(h,w)
        list_single_rect = [x,y,x+w,y+h]
        list_all_rect.append(list_single_rect)
        
    
        cv2.rectangle(display1,(x,y),( x + w, y + h ),(90,0,255),2)
    
    
    
    
    print("List of all rectanges detected is :",list_all_rect)
    
    cv2.imshow('marked area',display1)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    #for k in range(6) :
    merged_list = []
    merged_list = optimize_merge_rectangle(list_all_rect,5)
    print("Merged List is at threshold  :"+str(5) ,merged_list)
    for j in merged_list:
        widthi = abs(j[0]-j[2])
        print("width",widthi)
    display2 = image.copy()
    for i in merged_list:

      #crop_img = display2[i[1]:i[3],i[0]:i[2]]
      #cv2.imshow('crop',crop_img)
      #cv2.waitKey(0)
      #cv2.destroyAllWindows()

        cv2.rectangle(display2,(i[0],i[1]),(i[2], i[3]),(90,0,255),2)

    
        
    cv2.imshow('merged areas at threshold'+str(5),display2)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
directory_path = "/home/rahul/Downloads/FYP/legal_amount-20190214T035930Z-001/legal_amount/"
images = glob.glob(directory_path + "*.tif")
count = 0
for x in images :
    
    
        
    image = cv2.imread(x)
    height , width = image.shape[:2]
    do_segment(image)
# Out:
# Threshold Width 166
# Threshold Height 19
# Threshold Width 166
# Threshold Height 19
# 24 45
# Threshold Width 166
# Threshold Height 19
# Threshold Width 166
# Threshold Height 19
# 40 55
# Threshold Width 166
# Threshold Height 19
# 35 37
# Threshold Width 166
# Threshold Height 19
# 35 28
# Threshold Width 166
# Threshold Height 19
# 22 32
# Threshold Width 166
# Threshold Height 19
# 45 53
# Threshold Width 166
# Threshold Height 19
# Threshold Width 166
# Threshold Height 19
# Threshold Width 166
# Threshold Height 19
# Threshold Width 166
# Threshold Height 19
# Threshold Width 166
# Threshold Height 19
# List of all rectanges detected is : [[31, 18, 76, 42], [108, 11, 163, 51], [163, 22, 200, 57], [220, 19, 248, 54], [249, 29, 281, 51], [297, 12, 350, 57]]
# [[31, 18, 76, 42], [108, 11, 200, 57], [220, 19, 281, 54], [297, 12, 350, 57]]
# 45
# dist_left 999999999 dist_right 32
# 2 outside continue
# Merged List is at threshold  :5 [[31, 11, 200, 57], [220, 19, 281, 54], [297, 12, 350, 57]]
# width 169
# width 61
# width 53
# Threshold Width 166
# Threshold Height 17
# Threshold Width 166
# Threshold Height 17
# Threshold Width 166
# Threshold Height 17
# Threshold Width 166
# Threshold Height 17
# Threshold Width 166
# Threshold Height 17
# 51 132
# Threshold Width 166
# Threshold Height 17
# Threshold Width 166
# Threshold Height 17
# 39 28
# Threshold Width 166
# Threshold Height 17
# 32 115
# Threshold Width 166
# Threshold Height 17
# Threshold Width 166
# Threshold Height 17
# Threshold Width 166
# Threshold Height 17
# Threshold Width 166
# Threshold Height 17
# List of all rectanges detected is : [[140, 1, 272, 52], [315, 9, 343, 48], [330, 20, 445, 52]]
# [[140, 1, 272, 52], [315, 9, 445, 52]]
# Merged List is at threshold  :5 [[140, 1, 272, 52], [315, 9, 445, 52]]
# width 132
# width 130
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# 46 77
# Threshold Width 171
# Threshold Height 19
# 45 78
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# 43 59
# Threshold Width 171
# Threshold Height 19
# 35 61
# Threshold Width 171
# Threshold Height 19
# List of all rectanges detected is : [[112, 7, 189, 53], [208, 8, 286, 53], [340, 6, 399, 49], [400, 19, 461, 54]]
# [[112, 7, 189, 53], [208, 8, 286, 53], [340, 6, 461, 54]]
# Merged List is at threshold  :5 [[112, 7, 189, 53], [208, 8, 286, 53], [340, 6, 461, 54]]
# width 77
# width 78
# width 121
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# 28 24
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# 36 73
# Threshold Width 171
# Threshold Height 19
# 23 54
# Threshold Width 171
# Threshold Height 19
# 27 24
# Threshold Width 171
# Threshold Height 19
# 20 20
# Threshold Width 171
# Threshold Height 19
# 20 18
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# 27 18
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# 31 27
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# Threshold Width 171
# Threshold Height 19
# List of all rectanges detected is : [[146, 12, 170, 40], [235, 12, 308, 48], [335, 20, 389, 43], [421, 14, 445, 41], [447, 20, 467, 40], [470, 18, 488, 38], [490, 22, 508, 49], [567, 18, 594, 49]]
# [[146, 12, 170, 40], [235, 12, 308, 48], [335, 20, 389, 43], [421, 14, 508, 49], [567, 18, 594, 49]]
# 24
# dist_left 999999999 dist_right 65
# 27
# dist_left 59 dist_right 999999999
# Merged List is at threshold  :5 [[146, 12, 210, 40], [235, 12, 308, 48], [335, 20, 389, 43], [421, 14, 508, 49], [567, 18, 634, 49]]
# width 64
# width 73
# width 54
# width 87
# width 67
# Threshold Width 171
# Threshold Height 17
# Threshold Width 171
# Threshold Height 17
# 37 32
# Threshold Width 171
# Threshold Height 17
# 26 47
# Threshold Width 171
# Threshold Height 17
# 33 74
# Threshold Width 171
# Threshold Height 17
# Threshold Width 171
# Threshold Height 17
# Threshold Width 171
# Threshold Height 17
# 38 56
# Threshold Width 171
# Threshold Height 17
# Threshold Width 171
# Threshold Height 17
# 22 32
# Threshold Width 171
# Threshold Height 17
# Threshold Width 171
# Threshold Height 17
# 39 34
# Threshold Width 171
# Threshold Height 17
# 34 26
# Threshold Width 171
# Threshold Height 17
# 23 9
# Threshold Width 171
# Threshold Height 17
# 21 41
# Threshold Width 171
# Threshold Height 17
# 46 124
# Threshold Width 171
# Threshold Height 17
# Threshold Width 171
# Threshold Height 17
# 31 41
# Threshold Width 171
# Threshold Height 17
# Threshold Width 171
# Threshold Height 17
# Threshold Width 171
# Threshold Height 17
# List of all rectanges detected is : [[51, 13, 83, 50], [73, 24, 120, 50], [138, 16, 212, 49], [227, 12, 283, 50], [284, 28, 316, 50], [320, 13, 354, 52], [404, 15, 430, 49], [427, 25, 436, 48], [439, 27, 480, 48], [507, 1, 631, 47], [634, 14, 675, 45]]
# [[51, 13, 120, 50], [138, 16, 212, 49], [227, 12, 354, 52], [404, 15, 480, 49], [507, 1, 675, 47]]
# Merged List is at threshold  :5 [[51, 13, 120, 50], [138, 16, 212, 49], [227, 12, 354, 52], [404, 15, 480, 49], [507, 1, 675, 47]]
# width 69
# width 74
# width 127
# width 76
# width 168
